# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns
import scipy.stats as ss
from pylab import *

gamma = []

# %%
#expanded = []
#for i in range(len(data)):
#    k = data.iloc[i,0]
#    Nk = data.iloc[i,1]
#    newval = [k]*Nk
#    expanded += newval
    
#df = pd.DataFrame({'object':expanded})

# %% [markdown]
# # Question 1 #

# %%
data = pd.read_csv('textfile1.txt', sep=" ", header=None)
data.columns = ["k", "Nk"]
sum2 = np.cumsum(data['Nk'])
data['y'] = sum2

# %%
plt.figure(figsize=(12,7))
plt.xlabel("log10(k)")
plt.ylabel("log10(probabilty N >= k)")
plt.scatter(np.log10(data["k"]),np.log10(data['y']),marker = ",")
plt.axvline(x=4, ymin=.1, ymax=.9,color = 'orange')
plt.axvline(x=6.9, ymin=.1, ymax=.9,color = 'orange')
plt.axvline(x=7.3, ymin=.1, ymax=.9,color = 'green')
plt.axvline(x=9, ymin=.1, ymax=.9,color = 'green')


plt.show()

# %% [markdown]
# # Question 2

# %%
lowerhalf = data[np.log10(data['k']) > 4]
lowerhalf = lowerhalf[log10(lowerhalf['k']) <=6.9]
upperhalf = data[np.log10(data['k']) >= 7.3]
upperhalf = upperhalf[log10(upperhalf['k']) <=9]

# %%
plt.figure(figsize=(12,7))

slope,intercept, r_value, p_value, std_error = stats.linregress(np.log10(lowerhalf["k"]),np.log10(lowerhalf['y']))
Y_pred = slope *np.log10(lowerhalf["k"]) + intercept

ci = 1.96 * np.std(Y_pred)/np.mean(Y_pred)

plt.plot(np.log10(lowerhalf["k"]), Y_pred, color = 'magenta')
plt.scatter(np.log10(lowerhalf["k"]),np.log10(lowerhalf['y']),marker = ".")
plt.xlabel("log10(k)")
plt.ylabel("log10(probabilty N >= k)")
plt.fill_between(np.log10(lowerhalf['k']), (Y_pred-ci), (Y_pred+ci), color='b', alpha=.1)
plt.axvline(x=4, ymin=.05, ymax=.95,color = 'orange')
plt.axvline(x=6.9, ymin=.05, ymax=.95,color = 'orange')
plt.show()

print("gamma = ", slope)
print("ci = ", ci)
print("intercept", intercept)

gamma.append(slope)

gamma_minus_1 = []
gamma_minus_1.append(slope-1)
print('(gamma-1)', (slope-1))
# Out:
# gamma =  -0.6505843508372097
# ci =  0.1559044665226285
# intercept 8.485550112364788
# (gamma-1) -1.6505843508372098

# %%
slope,intercept, r_value, p_value, std_error = stats.linregress(np.log10(upperhalf["k"]),np.log10(upperhalf['y']))
Y_pred = slope *np.log10(upperhalf["k"]) + intercept

ci = 1.96 * np.std(Y_pred)/np.mean(Y_pred)


plt.figure(figsize=(12,7))
plt.xlabel("log10(k)")
plt.ylabel("log10(probabilty N >= k)")
plt.scatter(np.log10(upperhalf["k"]),np.log10(upperhalf['y']),marker = ".")
plt.plot(np.log10(upperhalf["k"]) , Y_pred, color = 'red')
plt.fill_between(np.log10(upperhalf["k"]), (Y_pred-ci), (Y_pred+ci), color='b', alpha=.1)
plt.axvline(x=7.3, ymin=.05, ymax=.95,color = 'green')
plt.axvline(x=9, ymin=.05, ymax=.95,color = 'green')
plt.show()

print("gamma = ", slope)
print("ci = ", ci)
print("intercept", intercept)

gamma.append(slope)

gamma_minus_1.append(slope-1)
print('(gamma-1)', (slope-1))
# Out:
# gamma =  -1.0904217109832035
# ci =  0.22469332745022616
# intercept 11.619873065631253
# (gamma-1) -2.0904217109832035

# %% [markdown]
# # Question 3 and 4

# %%
newdata = pd.read_csv('rawtextfile.txt', sep=" ", header=None)
newdata.columns = ['k']
k_sorted = sorted(newdata['k'],reverse = True)
newdata['k'] = k_sorted

# %%
log10x = np.log10(np.array(range(1, len(newdata['k']) + 1)))
log10frequency = np.log10(np.array(newdata['k']))

plt.figure(figsize=(12,7))
plt.xlabel("log10 rank k")
plt.ylabel("log10 frequency k")
plt.scatter(log10x,log10frequency,marker = ".")
plt.axhline(y=4, xmin=.05, xmax=.99,color = 'orange')
plt.axhline(y=6.9, xmin=.05, xmax=.999,color = 'orange')
plt.axhline(y=7.3, xmin=.05, xmax=.99,color = 'green')
plt.axhline(y=9, xmin=.05, xmax=.99,color = 'green')

plt.show()

# %%
upperhalf = newdata[np.log10(newdata['k']) >= 7]


log10x = np.log10(np.array(range(1, len(upperhalf['k']) + 1)))
log10frequency = np.log10(np.array(upperhalf['k']))

slope,intercept, r_value, p_value, std_error = stats.linregress(log10x,log10frequency)

Y_pred = slope *log10x + intercept

ci = 1.96 * np.std(Y_pred)/np.mean(Y_pred)

plt.figure(figsize=(12,7))
plt.xlabel("rank k")
plt.ylabel("frequency k")
plt.scatter(log10x,log10frequency,marker = ".")
plt.plot(log10x , Y_pred, color = 'red')
plt.fill_between(log10x, (Y_pred-ci), (Y_pred+ci), color='b', alpha=.1)
plt.axhline(y=7.3, xmin=.05, xmax=.99,color = 'green')
plt.axhline(y=9, xmin=.05, xmax=.99,color = 'green')

plt.show()
alpha = []
print("alpha = ",slope)
print("ci = ", ci)
print("intercept", intercept)
alpha.append(slope)
# Out:
# alpha =  -0.9875784322814256
# ci =  0.11221030778109467
# intercept 10.871730902487322

# %%
lowerhalf = newdata[np.log10(newdata['k']) <100]

log10x = np.log10(np.array(range(1, len(lowerhalf['k']) + 1)))
log10frequency = np.log10(np.array(lowerhalf['k']))

slope,intercept, r_value, p_value, std_error = stats.linregress(log10x,log10frequency)

Y_pred = slope *log10x + intercept

ci = 1.96 * np.std(Y_pred)/np.mean(Y_pred)

plt.figure(figsize=(12,7))
plt.xlabel("log10 rank k")
plt.ylabel("log10 frequency k")
plt.scatter(log10x,log10frequency,marker = ".")
plt.plot(log10x , Y_pred, color = 'red')
plt.fill_between(log10x, (Y_pred-ci), (Y_pred+ci), color='b', alpha=.1)
plt.axhline(y=4, xmin=.05, xmax=.99,color = 'orange')
plt.axhline(y=6.9, xmin=.05, xmax=.99,color = 'orange')

plt.show()
print("alpha = ",slope)
print("ci = ", ci)
print("intercept", intercept)
alpha.append(slope)
# Out:
# alpha =  -1.469308717107174
# ci =  0.28147172493265304
# intercept 12.683765193944058

# %%
#alpha = 1/gamma-1
print('alpha:   ', alpha)
print('gamma', gamma)
print('neg_gamma', gamma_minus_1)


expected_alpha_yellow = 1/(gamma_minus_1[1])
expected_alpha_green = 1/(gamma_minus_1[0])

print('yellow')
print(abs(expected_alpha_yellow), abs(alpha[1]))
print('green')
print(abs(expected_alpha_green), abs(alpha[0]))

#list reasons why error, im human, with eyes
# Out:
# alpha:    [-0.9875784322814256, -1.469308717107174]
# gamma [-0.6505843508372097, -1.0904217109832035]
# neg_gamma [-1.6505843508372098, -2.0904217109832035]
# yellow
# 0.4783723756531703 1.469308717107174
# green
# 0.6058460444586062 0.9875784322814256

# %% [markdown]
# # Question 6

# %%
girls1952 = pd.read_csv('names-girls1952.txt', sep=",", header=None)
girls2002 = pd.read_csv('names-girls2002.txt', sep=",", header=None)
boys1952 = pd.read_csv('names-boys1952.txt', sep=",", header=None)
boys2002 = pd.read_csv('names-girls2002.txt', sep=",", header=None)

# %%
girls1952.columns = ["name", "gender", "frequency"]
sum2 = np.cumsum(girls1952['frequency'])
girls1952['y'] = sum2

girls2002.columns = ["name", "gender", "frequency"]
sum2 = np.cumsum(girls2002['frequency'])
girls2002['y'] = sum2

boys1952.columns = ["name", "gender", "frequency"]
sum2 = np.cumsum(boys1952['frequency'])
boys1952['y'] = sum2

boys2002.columns = ["name", "gender", "frequency"]
sum2 = np.cumsum(boys2002['frequency'])
boys2002['y'] = sum2

# %%
plt.figure(figsize=(12,7))

plt.axvline(x=1, ymin=.05, ymax=.99,color = 'orange')
plt.axvline(x=2.85, ymin=.05, ymax=.999,color = 'orange')

plt.scatter(np.log10(girls1952["frequency"]),np.log10(girls1952['y']),marker = ".")
plt.xlabel("frequency")

cutoff = girls1952[np.log10(girls1952['frequency']) <=2.85]
cutoff = cutoff[np.log10(cutoff['frequency']) >=1]


slope,intercept, r_value, p_value, std_error = stats.linregress(np.log10(cutoff['frequency']),np.log10(cutoff['y']))
Y_pred = slope *np.log10(cutoff["frequency"]) + intercept
ci = 1.96 * np.std(Y_pred)/np.mean(Y_pred)
plt.ylabel("log10(probabilty N >= freqency)")
plt.plot(np.log10(cutoff["frequency"]), Y_pred, color = 'magenta')
plt.fill_between(np.log10(cutoff['frequency']), (Y_pred-ci), (Y_pred+ci), color='b', alpha=.1)


plt.show()

print("gamma = ", slope)
print("ci = ", ci)
print("intercept", intercept)
# Out:
# gamma =  -0.026125951607952017
# ci =  0.003818330872617296
# intercept 6.293270320691437

# %%
newdata = girls1952
names_sorted = sorted(newdata['frequency'],reverse = True)
newdata['frequency'] = names_sorted

# %%
log10x = np.log10(np.array(range(1, len(newdata['frequency']) + 1)))
log10frequency = np.log10(np.array(newdata['frequency']))

slope,intercept, r_value, p_value, std_error = stats.linregress(log10x,log10frequency)

Y_pred = slope *log10x + intercept

ci = 1.96 * np.std(Y_pred)/np.mean(Y_pred)

plt.figure(figsize=(12,7))
plt.xlabel("log10 rank k")
plt.ylabel("log10 frequency k")
plt.scatter(log10x,log10frequency,marker = ".")
plt.plot(log10x , Y_pred, color = 'red')
plt.fill_between(log10x, (Y_pred-ci), (Y_pred+ci), color='b', alpha=.1)
plt.axhline(y=1, xmin=.05, xmax=.99,color = 'orange')
plt.axhline(y=2.85, xmin=.05, xmax=.99,color = 'orange')

plt.show()


print("alpha = ", slope)
print("ci = ", ci)
print("intercept", intercept)
# Out:
# alpha =  -1.5889849949405832
# ci =  1.01498199579644
# intercept 6.685179666906345

# %%
plt.figure(figsize=(12,7))


plt.axvline(x=1, ymin=.05, ymax=.99,color = 'orange')
plt.axvline(x=2.6, ymin=.05, ymax=.999,color = 'orange')

cutoff = girls2002[np.log10(girls2002['frequency']) <=2.6]
cutoff = cutoff[np.log10(cutoff['frequency']) >=1]

plt.scatter(np.log10(girls2002["frequency"]),np.log10(girls2002['y']),marker = ".")
plt.xlabel("frequency")
slope,intercept, r_value, p_value, std_error = stats.linregress(np.log10(cutoff['frequency']),np.log10(cutoff['y']))
Y_pred = slope *np.log10(cutoff["frequency"]) + intercept
ci = 1.96 * np.std(Y_pred)/np.mean(Y_pred)
plt.ylabel("log10(probabilty N >= freqency)")
plt.plot(np.log10(cutoff["frequency"]), Y_pred, color = 'magenta')
plt.fill_between(np.log10(cutoff['frequency']), (Y_pred-ci), (Y_pred+ci), color='b', alpha=.1)


plt.show()

print("gamma = ", slope)
print("ci = ", ci)
print("intercept", intercept)
# Out:
# gamma =  -0.06799456222732941
# ci =  0.008477295889673877
# intercept 6.313624749369296

# %%
newdata = girls2002
names_sorted = sorted(newdata['frequency'],reverse = True)
newdata['frequency'] = names_sorted

# %%
log10x = np.log10(np.array(range(1, len(newdata['frequency']) + 1)))
log10frequency = np.log10(np.array(newdata['frequency']))

slope,intercept, r_value, p_value, std_error = stats.linregress(log10x,log10frequency)

Y_pred = slope *log10x + intercept

ci = 1.96 * np.std(Y_pred)/np.mean(Y_pred)

plt.figure(figsize=(12,7))
plt.xlabel("log10 rank k")
plt.ylabel("log10 frequency k")
plt.scatter(log10x,log10frequency,marker = ".")
plt.plot(log10x , Y_pred, color = 'red')
plt.fill_between(log10x, (Y_pred-ci), (Y_pred+ci), color='b', alpha=.1)
plt.axhline(y=1, xmin=.05, xmax=.99,color = 'orange')
plt.axhline(y=2.6, xmin=.05, xmax=.99,color = 'orange')

plt.show()
print("alpha = ", slope)
print("ci = ", ci)
print("intercept", intercept)
# Out:
# alpha =  -1.2982291198886773
# ci =  0.9010892075287118
# intercept 6.187710789259508

# %%
plt.figure(figsize=(12,7))


plt.axvline(x=1, ymin=.05, ymax=.99,color = 'orange')
plt.axvline(x=3.2, ymin=.05, ymax=.999,color = 'orange')

cutoff = boys1952[np.log10(boys1952['frequency']) <=3.2]
cutoff = cutoff[np.log10(cutoff['frequency']) >=1]

slope,intercept, r_value, p_value, std_error = stats.linregress(np.log10(cutoff['frequency']),np.log10(cutoff['y']))
Y_pred = slope *np.log10(cutoff["frequency"]) + intercept
ci = 1.96 * np.std(Y_pred)/np.mean(Y_pred)
plt.ylabel("log10(probabilty N >= freqency)")
plt.plot(np.log10(cutoff["frequency"]), Y_pred, color = 'magenta')
plt.fill_between(np.log10(cutoff['frequency']), (Y_pred-ci), (Y_pred+ci), color='b', alpha=.1)

plt.scatter(np.log10(boys1952["frequency"]),np.log10(boys1952['y']),marker = ".")
plt.xlabel("frequency")


plt.show()

print("gamma = ", slope)
print("ci = ", ci)
print("intercept", intercept)
# Out:
# gamma =  -0.020753908831859947
# ci =  0.0034690849180088277
# intercept 6.310557460599025

# %%
newdata = boys1952
names_sorted = sorted(newdata['frequency'],reverse = True)
newdata['frequency'] = names_sorted

# %%
log10x = np.log10(np.array(range(1, len(newdata['frequency']) + 1)))
log10frequency = np.log10(np.array(newdata['frequency']))

slope,intercept, r_value, p_value, std_error = stats.linregress(log10x,log10frequency)

Y_pred = slope *log10x + intercept

ci = 1.96 * np.std(Y_pred)/np.mean(Y_pred)

plt.figure(figsize=(12,7))
plt.xlabel("log10 rank k")
plt.ylabel("log10 frequency k")
plt.scatter(log10x,log10frequency,marker = ".")
plt.plot(log10x , Y_pred, color = 'red')
plt.fill_between(log10x, (Y_pred-ci), (Y_pred+ci), color='b', alpha=.1)
plt.axhline(y=1, xmin=.05, xmax=.99,color = 'orange')
plt.axhline(y=3.2, xmin=.05, xmax=.99,color = 'orange')

plt.show()
print("alpha = ", slope)
print("ci = ", ci)
print("intercept", intercept)
# Out:
# alpha =  -1.7052381284557867
# ci =  1.039437101234751
# intercept 6.838157165668639

# %%
plt.figure(figsize=(12,7))

plt.scatter(np.log10(boys2002["frequency"]),np.log10(boys2002['y']),marker = ".")
plt.xlabel("frequency")

plt.axvline(x=1.1, ymin=.05, ymax=.99,color = 'orange')
plt.axvline(x=2.8, ymin=.05, ymax=.999,color = 'orange')

cutoff = boys2002[np.log10(boys2002['frequency']) >=1.1]
cutoff = cutoff[np.log10(cutoff['frequency']) <=2.8]

slope,intercept, r_value, p_value, std_error = stats.linregress(np.log10(cutoff['frequency']),np.log10(cutoff['y']))
Y_pred = slope *np.log10(cutoff["frequency"]) + intercept
ci = 1.96 * np.std(Y_pred)/np.mean(Y_pred)
plt.ylabel("log10(probabilty N >= freqency)")
plt.plot(np.log10(cutoff["frequency"]), Y_pred, color = 'magenta')
plt.fill_between(np.log10(cutoff['frequency']), (Y_pred-ci), (Y_pred+ci), color='b', alpha=.1)
plt.show()

print("gamma = ", slope)
print("ci = ", ci)
print("intercept", intercept)
# Out:
# gamma =  -0.07623623526918473
# ci =  0.00986490910299962
# intercept 6.326853747613669

# %%
newdata = boys2002
names_sorted = sorted(newdata['frequency'],reverse = True)
newdata['frequency'] = names_sorted

# %%
log10x = np.log10(np.array(range(1, len(newdata['frequency']) + 1)))
log10frequency = np.log10(np.array(newdata['frequency']))

slope,intercept, r_value, p_value, std_error = stats.linregress(log10x,log10frequency)

Y_pred = slope *log10x + intercept

ci = 1.96 * np.std(Y_pred)/np.mean(Y_pred)

plt.figure(figsize=(12,7))
plt.xlabel("log10 rank k")
plt.ylabel("log10 frequency k")
plt.scatter(log10x,log10frequency,marker = ".")
plt.plot(log10x , Y_pred, color = 'red')
plt.fill_between(log10x, (Y_pred-ci), (Y_pred+ci), color='b', alpha=.1)
plt.axhline(y=1.1, xmin=.05, xmax=.99,color = 'orange')
plt.axhline(y=2.8, xmin=.05, xmax=.99,color = 'orange')

plt.show()
print("alpha = ", slope)
print("ci = ", ci)
print("intercept", intercept)
# Out:
# alpha =  -1.2982291198886773
# ci =  0.9010892075287118
# intercept 6.187710789259508
